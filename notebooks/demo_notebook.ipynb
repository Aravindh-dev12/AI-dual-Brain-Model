# %% [markdown]
# # Demo Notebook

# %%
import requests
resp = requests.post('http://127.0.0.1:8000/ask', json={'question':'Write a Python function to compute Fibonacci numbers efficiently.'})
print(resp.json())
